# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("kratos.png")

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=588x713>

# %% [markdown]
# <h1>Display only the top left corner of 100x100 pixels.</h1>

# %%
image_array = np.array(image)

# %%
corner_img = image_array[0:100, 0:100]

# %%
plt.imshow(corner_img)
plt.show()

# %% [markdown]
# <h1>Show the three color channels</h1>

# %%
R = image_array[:,:,0]
G = image_array[:,:,1]
B = image_array[:,:,2]

# %%
plt.figure(figsize=(10,10))

# %%
plt.subplot(1,3,1)
plt.imshow(R, cmap='Reds')
plt.show()

plt.subplot(1,3,2)
plt.imshow(G, cmap='Greens')
plt.show()

plt.subplot(1,3,3)
plt.imshow(B, cmap='Blues')
plt.show()

# %% [markdown]
# <h1>Modify the top 100 × 100 pixels to a value of 210 and display the resulting image</h1>

# %%
image_array[0:100, 0:100] = 210

# %%
plt.imshow(image_array)
plt.show()
